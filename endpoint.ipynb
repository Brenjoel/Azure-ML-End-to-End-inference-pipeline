# %%
from azure.identity import DefaultAzureCredential
from azure.ai.ml import MLClient , command , Input , Output
from azure.ai.ml.entities import Data , Environment , Model , ComputeInstance , AmlCompute
from azure.ai.ml.constants import AssetTypes

from datetime import datetime
from zoneinfo import ZoneInfo


from azure.ai.ml.dsl import pipeline

# %%
from azure.ai.ml import MLClient
from azure.ai.ml.dsl import pipeline
from azure.ai.ml.entities import (
    BatchEndpoint,
    BatchDeployment,
    BatchRetrySettings
)
from azure.identity import DefaultAzureCredential , AzureCliCredential

# %%
# Connect mlClient
credential = DefaultAzureCredential()

# ml_client = MLClient.from_config(
#     credential=DefaultAzureCredential()
# )

ml_client = MLClient.from_config(
    credential=AzureCliCredential()
)
# Out:
# Found the config file in: /config.json
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %%
# ml_client = MLClient(
#     credential=credential,
#     subscription_id = ml_client.subscription_id,
#     resource_group_name = ml_client.resource_group_name,
#     workspace_name = ml_client.workspace_name
# )

ml_client = MLClient(
    credential=credential,
    subscription_id = '49297e8f-2e51-410c-aee9-69db39628913',
    resource_group_name = 'dp-100_trail',
    workspace_name = 'dp-100'
)
# Out:
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented

# %%
job = ml_client.batch_endpoints.invoke(
    endpoint_name="flight-delay-batch-endpoint",
    input="./data/1.csv"
)

print(job.name)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/ai/ml/_utils/_endpoint_utils.py:178, in validate_response(response)
#     177 try:
# --> 178     r_json = response.json()
#     179 except ValueError as e:
#     180     # exception is not in the json format
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/core/rest/_http_response_impl.py:331, in _HttpResponseBaseImpl.json(self)
#     330 if not self._json:
# --> 331     self._json = loads(self.text())
#     332 return self._json
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# The above exception was the direct cause of the following exception:
#
# MlException                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 job = ml_client.batch_endpoints.invoke(
#       2     endpoint_name="flight-delay-batch-endpoint",
#       3     input="./data/1.csv"
#       4 )
#       6 print(job.name)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/core/tracing/decorator.py:138, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     136             for key, value in span_attributes.items():
#     137                 span.add_attribute(key, value)  # type: ignore
# --> 138             return func(*args, **kwargs)
#     139 else:
#     140     # Native path
#     141     config = {}
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/ai/ml/_telemetry/activity.py:288, in monitor_with_activity.<locals>.monitor.<locals>.wrapper(*args, **kwargs)
#     284     with tracer.start_as_current_span(ACTIVITY_SPAN):
#     285         with log_activity(
#     286             logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions
#     287         ):
# --> 288             return f(*args, **kwargs)
#     289 elif hasattr(logger, "package_logger"):
#     290     with log_activity(logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions):
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/ai/ml/operations/_batch_endpoint_operations.py:401, in BatchEndpointOperations.invoke(self, endpoint_name, deployment_name, inputs, **kwargs)
#     399     retry_msg = "Max retry attempts reached while trying to connect to server. Please check connection and invoke again."  # pylint: disable=line-too-long
#     400     raise MlException(message=retry_msg, no_personal_data_message=retry_msg, target=ErrorTarget.BATCH_ENDPOINT)
# --> 401 validate_response(response)
#     402 batch_job = json.loads(response.text())
#     403 return BatchJobResource.deserialize(batch_job)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/azure/ai/ml/_utils/_endpoint_utils.py:182, in validate_response(response)
#     179     except ValueError as e:
#     180         # exception is not in the json format
#     181         msg = response.content.decode("utf-8")
# --> 182         raise MlException(message=msg, no_personal_data_message=msg) from e
#     183 failure_msg = r_json.get("error", {}).get("message", response)
#     184 error_map = {
#     185     401: ClientAuthenticationError,
#     186     404: ResourceNotFoundError,
#    (...)
#     189     424: HttpResponseError,
#     190 }
#
# MlException: Tenant mismatch: Token tenant does not match resource tenant
